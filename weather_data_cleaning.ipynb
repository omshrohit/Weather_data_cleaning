# %% [markdown]
# data cleaning

# %% [markdown]
# 1st import libraries

# %%
import pandas as pd

# %% [markdown]
# 2nd load data

# %%
weather=pd.read_csv('nyc_weather.csv',na_values=['T'])
weather
# Out:
#           EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 0    1/1/2016           38        23        52                 30.03
# 1    1/2/2016           36        18        46                 30.02
# 2    1/3/2016           40        21        47                 29.86
# 3    1/4/2016           25         9        44                 30.05
# 4    1/5/2016           20        -3        41                 30.57
# 5    1/6/2016           33         4        35                 30.50
# 6    1/7/2016           39        11        33                 30.28
# 7    1/8/2016           39        29        64                 30.20
# 8    1/9/2016           44        38        77                 30.16
# 9   1/10/2016           50        46        71                 29.59
# 10  1/11/2016           33         8        37                 29.92
# 11  1/12/2016           35        15        53                 29.85
# 12  1/13/2016           26         4        42                 29.94
# ...

# %% [markdown]
# 3rd Understanding the data structure of data

# %%
weather.shape
# Out:
# (31, 11)

# %%
weather.head(1)
# Out:
#         EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 0  1/1/2016           38        23        52                 30.03
#
#    VisibilityMiles  WindSpeedMPH  PrecipitationIn  CloudCover Events  \
# 0               10           8.0              0.0           5    NaN
#
#    WindDirDegrees
# 0             281

# %%
weather.columns
# Out:
# Index(['EST', 'Temperature', 'DewPoint', 'Humidity', 'Sea Level PressureIn',
#        'VisibilityMiles', 'WindSpeedMPH', 'PrecipitationIn', 'CloudCover',
#        'Events', 'WindDirDegrees'],
#       dtype='object')

# %% [markdown]
# data type checking

# %%
weather.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31 entries, 0 to 30
# Data columns (total 11 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   EST                   31 non-null     object
#  1   Temperature           31 non-null     int64
#  2   DewPoint              31 non-null     int64
#  3   Humidity              31 non-null     int64
#  4   Sea Level PressureIn  31 non-null     float64
#  5   VisibilityMiles       31 non-null     int64
#  6   WindSpeedMPH          28 non-null     float64
#  7   PrecipitationIn       24 non-null     float64
#  8   CloudCover            31 non-null     int64
#  9   Events                9 non-null      object
#  10  WindDirDegrees        31 non-null     int64
# dtypes: float64(3), int64(6), object(2)
# memory usage: 2.8+ KB

# %%
weather.describe()
# Out:
#        Temperature   DewPoint   Humidity  Sea Level PressureIn  \
# count    31.000000  31.000000  31.000000             31.000000
# mean     34.677419  17.838710  51.677419             29.992903
# std       7.639315  11.378626  11.634395              0.237237
# min      20.000000  -3.000000  33.000000             29.520000
# 25%      29.000000  10.000000  44.500000             29.855000
# 50%      35.000000  18.000000  50.000000             30.010000
# 75%      39.500000  23.000000  55.000000             30.140000
# max      50.000000  46.000000  78.000000             30.570000
#
#        VisibilityMiles  WindSpeedMPH  PrecipitationIn  CloudCover  \
# count        31.000000     28.000000        24.000000   31.000000
# mean          9.193548      6.892857         0.183750    3.129032
# std           1.939405      2.871821         0.583317    2.629853
# min           1.000000      2.000000         0.000000    0.000000
# ...

# %% [markdown]
# 4th handle missing data

# %%
weather.isnull().sum()
# Out:
# EST                      0
# Temperature              0
# DewPoint                 0
# Humidity                 0
# Sea Level PressureIn     0
# VisibilityMiles          0
# WindSpeedMPH             3
# PrecipitationIn          7
# CloudCover               0
# Events                  22
# WindDirDegrees           0
# dtype: int64

# %%
weather.isnull().sum()/weather.shape[0]*100
# Out:
# EST                      0.000000
# Temperature              0.000000
# DewPoint                 0.000000
# Humidity                 0.000000
# Sea Level PressureIn     0.000000
# VisibilityMiles          0.000000
# WindSpeedMPH             9.677419
# PrecipitationIn         22.580645
# CloudCover               0.000000
# Events                  70.967742
# WindDirDegrees           0.000000
# dtype: float64

# %%
weather['EST']=pd.to_datetime(weather['EST'])

# %%
type(weather['EST'][0])
# Out:
# pandas._libs.tslibs.timestamps.Timestamp

# %%
weather.set_index('EST',inplace=True)

# %%
weather['WindSpeedMPH'].interpolate(method='time',inplace=True)
# Out:
# <ipython-input-75-136f08f182c7>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   weather['WindSpeedMPH'].interpolate(method='time',inplace=True)

# %%
weather['PrecipitationIn'].interpolate(method='time',inplace=True)
# Out:
# <ipython-input-76-685f097d459e>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   weather['PrecipitationIn'].interpolate(method='time',inplace=True)

# %%
weather[['WindSpeedMPH','PrecipitationIn']]
# Out:
#             WindSpeedMPH  PrecipitationIn
# EST
# 2016-01-01      8.000000            0.000
# 2016-01-02      7.000000            0.000
# 2016-01-03      8.000000            0.000
# 2016-01-04      9.000000            0.000
# 2016-01-05      5.000000            0.000
# 2016-01-06      4.000000            0.000
# 2016-01-07      2.000000            0.000
# 2016-01-08      4.000000            0.000
# 2016-01-09      8.000000            0.900
# 2016-01-10      7.333333            1.800
# 2016-01-11      6.666667            0.000
# 2016-01-12      6.000000            0.000
# 2016-01-13     10.000000            0.000
# 2016-01-14      5.000000            0.080
# 2016-01-15      5.000000            0.160
# 2016-01-16      7.000000            0.240
# 2016-01-17      6.000000            0.050
# 2016-01-18     12.000000            0.025
# 2016-01-19     11.000000            0.000
# 2016-01-20      6.000000            0.000
# 2016-01-21      6.000000            0.000
# ...

# %%
weather['Events'].fillna('no event',inplace=True)
# Out:
# <ipython-input-78-cd4ec134f7bf>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   weather['Events'].fillna('no event',inplace=True)

# %%
weather.isnull().sum()
# Out:
# Temperature             0
# DewPoint                0
# Humidity                0
# Sea Level PressureIn    0
# VisibilityMiles         0
# WindSpeedMPH            0
# PrecipitationIn         0
# CloudCover              0
# Events                  0
# WindDirDegrees          0
# dtype: int64

# %%
print('Data is ready to Data Analysis---')
# Out:
# Data is ready to Data Analysis---

# %%
weather
# Out:
#             Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# EST
# 2016-01-01           38        23        52                 30.03
# 2016-01-02           36        18        46                 30.02
# 2016-01-03           40        21        47                 29.86
# 2016-01-04           25         9        44                 30.05
# 2016-01-05           20        -3        41                 30.57
# 2016-01-06           33         4        35                 30.50
# 2016-01-07           39        11        33                 30.28
# 2016-01-08           39        29        64                 30.20
# 2016-01-09           44        38        77                 30.16
# 2016-01-10           50        46        71                 29.59
# 2016-01-11           33         8        37                 29.92
# 2016-01-12           35        15        53                 29.85
# 2016-01-13           26         4        42                 29.94
# ...
